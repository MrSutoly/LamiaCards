# %%
import pandas as pd
import tensorflow as tf
import sklearn
import scikeras #imports

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.models import Sequential
from tensorflow.keras import backend as k

X = pd.read_csv('entradas_breast.csv')
y = pd.read_csv('saidas_breast.csv') #imports e entradas de do csv

# %%
def criar_rede():
    
    k.clear_session()
    rede_neural = Sequential([
        tf.keras.layers.InputLayer(shape = (30,)),
        tf.keras.layers.Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform'),
        tf.keras.layers.Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform'),
        tf.keras.layers.Dense(units = 1, activation = 'sigmoid') #funcao pra criar a rede neural com 2 camadas ocultas
    ])
    otimizador = tf.keras.optimizers.Adam(learning_rate = 0.001, clipvalue = 0.5) #otimizadors da rede
    rede_neural.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics = ['binary_accuracy']) #compilacao dela
    return rede_neural #e volta ela

# %%
rede_neural = KerasClassifier(model = criar_rede, epochs = 100, batch_size = 10) #definindo batch size, epochs pra rede

# %%
resultados = cross_val_score(estimator = rede_neural, X = X, y = y, cv = 10, scoring = 'accuracy') #fazendo o KFOLD dividindo em 10 pastas
# Out:
# I0000 00:00:1779564772.708529  252509 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1204 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/100
# I0000 00:00:1779564773.927499  252638 service.cc:153] XLA service 0x7efb5c0442a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779564773.927516  252638 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 3050 6GB Laptop GPU, Compute Capability 8.6 (Driver: 13.0.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.22.0)
# I0000 00:00:1779564773.944784  252638 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779564774.075589  252638 cuda_dnn.cc:461] Loaded cuDNN version 92200
# ...

# %%
print(resultados) #printa
# Out:
# [0.61403509 0.77192982 0.85964912 0.73684211 0.84210526 0.77192982
#  0.80701754 0.84210526 0.75438596 0.82142857]

# %%
resultados.mean() #media
# Out:
# np.float64(0.7821428571428571)

# %%
resultados.std() #devio padrao
# Out:
# np.float64(0.0683020909419142)

# %% [markdown]
# # DropOut aula

# %%
def criar_rede():
    
    k.clear_session()
    rede_neural = Sequential([
        tf.keras.layers.InputLayer(shape = (30,)),
        tf.keras.layers.Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform'),
        tf.keras.layers.Dropout(rate = 0.2),
        tf.keras.layers.Dense(units = 16, activation = 'relu', kernel_initializer = 'random_uniform'),
        tf.keras.layers.Dropout(rate = 0.2),
        tf.keras.layers.Dense(units = 1, activation = 'sigmoid') #funcao pra criar a rede neural com 2 camadas ocultas
    ])
    otimizador = tf.keras.optimizers.Adam(learning_rate = 0.001, clipvalue = 0.5) #otimizadors da rede
    rede_neural.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics = ['binary_accuracy']) #compilacao dela
    return rede_neural #e volta ela

# %%
rede_neural = KerasClassifier(model = criar_rede, epochs = 100, batch_size = 10) #definindo batch size, epochs pra rede

# %%
resultados = cross_val_score(estimator = rede_neural, X = X, y = y, cv = 10, scoring = 'accuracy') #fazendo o KFOLD dividindo em 10 pastas
# Out:
# Epoch 1/100
# I0000 00:00:1779565827.890096  252626 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_237766__.11
#  1/52 ━━━━━━━━━━━━━━━━━━━━ 1:19 2s/step - binary_accuracy: 0.5000 - loss: 2.6731
# I0000 00:00:1779565829.012207  252637 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_237766__.11
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - binary_accuracy: 0.6367 - loss: 1.3583
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.6523 - loss: 0.8087
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.7168 - loss: 0.6062
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.7285 - loss: 0.5707
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.7344 - loss: 0.6240
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - binary_accuracy: 0.7305 - loss: 0.6513
# Epoch 7/100
# ...

# %%
resultados #print
# Out:
# array([0.61403509, 0.8245614 , 0.94736842, 0.84210526, 0.89473684,
#        0.92982456, 0.9122807 , 0.9122807 , 0.85964912, 0.91071429])

# %%
resultados.mean() #media dos resultados
# Out:
# np.float64(0.8647556390977444)

# %%
resultados.std() #desvio padrao
# Out:
# np.float64(0.09143448845098591)
