# %%
print("Hello") #printa hello
# Out:
# Hello

# %%
1 + 1 #soma 1 + 1 e printa o resultado
# Out:
# 2

# %%
a = 1
print (a) #define a como 1 e printa a
# Out:
# 1

# %% [markdown]
# Tendo nocoes basicas do jupyter
