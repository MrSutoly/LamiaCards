# %% [markdown]
# Exercicio - Compras de Ecommerce

# %%
import pandas as pd

# %%
ecom = pd.read_csv('Ecommerce Purchases')

# %% [markdown]
# Verifique o head do DF

# %%
ecom.head()
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %% [markdown]
# Quantas linhas e colunas existem?

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Address           10000 non-null  object
#  1   Lot               10000 non-null  object
#  2   AM or PM          10000 non-null  object
#  3   Browser Info      10000 non-null  object
#  4   Company           10000 non-null  object
#  5   Credit Card       10000 non-null  int64
#  6   CC Exp Date       10000 non-null  object
#  7   CC Security Code  10000 non-null  int64
#  8   CC Provider       10000 non-null  object
#  9   Email             10000 non-null  object
#  10  Job               10000 non-null  object
#  11  IP Address        10000 non-null  object
#  12  Language          10000 non-null  object
#  13  Purchase Price    10000 non-null  float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# Quak e o preco de compra medio

# %%
ecom['Purchase Price'].mean()
# Out:
# np.float64(50.347302)

# %% [markdown]
# Quais foram os precos de compra mais altos e mais baixos?

# %%
ecom['Purchase Price'].max()
# Out:
# 99.99

# %%
ecom['Purchase Price'].min()
# Out:
# 0.0

# %% [markdown]
# Quantas pessoas tem ingles 'en' como sua lingua de escolha no site

# %%
ecom[ecom['Language'] == 'en'].shape
# Out:
# (1098, 14)

# %% [markdown]
# Quantas pessoas tem o cargo de Advogado?

# %%
ecom[ecom['Job'] == 'Lawyer'].shape
# Out:
# (30, 14)

# %% [markdown]
# Quantas pessoas fizeram a compra durante a AM e quantos fizeram a PM?

# %% [markdown]
# Sugestao, confuira value_counts()

# %%
ecom['AM or PM'].value_counts()
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %% [markdown]
# Quais sao os os 5 titulos de trabalho mais comuns?

# %%
ecom['Job'].head()
# Out:
# 0    Scientist, product/process development
# 1                         Drilling engineer
# 2                  Customer service manager
# 3                         Drilling engineer
# 4                               Fine artist
# Name: Job, dtype: object

# %% [markdown]
# Alguem fez uma compra que veio do lot:'90 WT', qual foi o preco da compra para esta transacao?

# %%
ecom[ecom['Lot'] == '90 WT']['Purchase Price']
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %% [markdown]
# Qual e o email da pessoa com o numero de cartao de credito: 4926535242672853

# %%
ecom[ecom['Credit Card'] == 4926535242672853]['Email']
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: object

# %% [markdown]
# Qantas pessoa tem o american express como seu fornecedor de cartao de credito *e* e fizeram uma compra acima de US $95?

# %%
ecom[(ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] > 95)].shape
# Out:
# (39, 14)

# %% [markdown]
# Dificil: quantas pessoas tem um cartao de credita que expira em 2025?

# %%
ecom['CC Exp Date'].str.contains('/25').sum()
# Out:
# np.int64(1033)

# %% [markdown]
# Dificil: quais sao os 5 princiapos provedores de email/hosts mais populares(por exemplo, gamil.com, yahoo.com, etc...)?

# %%
ecom['Email'].apply(lambda x: x.split('@')[1]).value_counts().head()
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
