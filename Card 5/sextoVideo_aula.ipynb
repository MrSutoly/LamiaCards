# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
values = np.random.uniform(-10.0, 10.0, 100000)

# %%
plt.hist(values)
# Out:
# (array([ 9978.,  9929.,  9729., 10189., 10101.,  9984., 10071., 10003.,
#          9896., 10120.]),
#  array([-9.99930979e+00, -7.99944065e+00, -5.99957152e+00, -3.99970238e+00,
#         -1.99983325e+00,  3.58819925e-05,  1.99990502e+00,  3.99977415e+00,
#          5.99964328e+00,  7.99951242e+00,  9.99938155e+00]),
#  <BarContainer object of 10 artists>)

# %%
from scipy.stats import norm

# %%
x = np.arange(-3, 3, 0.001)

# %%
plt.plot(x, norm.pdf(x))

# %%
mu = 5.0
sigma = 2.0 
values = np.random.normal(mu, sigma, 10000)

# %%
plt.hist(values, 50)
plt.show()

# %%
from scipy.stats import expon

# %%
x = np.arange(0, 10, 0.001)
plt.plot(x, expon.pdf(x))
plt.show()

# %%
from scipy.stats import binom

# %%
n, p = 10, 0.5
x = np.arange(0, 10, 0.001)
plt.plot(x, binom.pmf(x, n, p))

# %%
from scipy.stats import poisson

# %%
mu = 500
x = np.arange(400, 600, 0.5)
plt.plot(x, poisson.pmf(x, mu))

# %% [markdown]
# Whats the equivalent of a probability distribution function when using discrete instead of continuous data?

# %% [markdown]
# R) Funcao de densidade probabilidade
