# %%
print('test test 123') #printa test test 123 abaixo
# Out:
# test test 123

# %%
import pandas as pd #importa o pandas

# %%
df = pd.read_csv('../input/mrbeast-youtube-stats-daily/MrBeast_youtube_stats.csv') #le o csv

# %%
df.head() #pega as 5 primeiras linhas do df
# Out:
#             id                             title description  \
# 0  nAiKLoCP-kU      Reach the Money, Win $10,000         NaN
# 1  8krJy31Diow    Holding Bigger And Bigger Dogs         NaN
# 2  SWc8fI_9iqA    Ronaldo Teaches Me How To SIUU         NaN
# 3  R_BmT1OJw98  Every YouTube Play Button I Have         NaN
# 4  8bTQMDM4qvY  Spot The Fake Animal For $10,000         NaN
#
#                  publishTime     kind_stats  duration_seconds    viewCount  \
# 0  2025-02-14 18:15:00+00:00  youtube#video                25  505965805.0
# 1  2024-09-16 18:00:00+00:00  youtube#video                17  335705585.0
# 2  2024-12-01 17:00:00+00:00  youtube#video                15  356735401.0
# 3  2025-08-15 16:00:01+00:00  youtube#video                15  214226489.0
# 4  2024-07-19 16:00:00+00:00  youtube#video                40  627513260.0
#
#     likeCount  commentCount                          thumbnails.default.url  \
# ...

# %%
df.plot(x = 'viewCount', y = 'likeCount', kind = 'scatter', title = 'Mr. Beast Videos') #grafico que mostra a relacao entre likes e visualizacoes do mrBeast
# Out:
# <Axes: title={'center': 'Mr. Beast Videos'}, xlabel='viewCount', ylabel='likeCount'>
